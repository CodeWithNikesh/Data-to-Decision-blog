# %% [markdown]
# <a href="https://colab.research.google.com/github/nikesh11xx/Data-to-Decision-blog/blob/main/python_list_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# what are lists
# -  List is a data type where you can store multiple items under 1 name more technically, list act like dynamic array which means you can add more items on fly
# - list are hetrogenous
# - mutable
# - can be nested
# - items can be accessed
# - execuation speed of list is less  the array
# - list occupy more space to then array![Screenshot 2024-02-14 120807.png](data:image/png;base64,...)

# %%
# id() tell the memory location
a = 2
print(id(2))

# %% [markdown]
# Creating list

# %%
# empty
print([])

# 1d list
print([1,2,3])

#2d list
print([1,2,3,[4,5]]) # hetrogenous

# 3d list
print([[[1,2],[3,4],[5,6],[7,8]]])

# hetrogenous
print([1,'hello',True])

# using type conversion
print(list('Hello'))

# %% [markdown]
# accessing items from a list
#   - Indexing is like a picking a specific items from a list
#   - slicing is like taking a piece of that list

# %%
# indexing
l =[1,2,3,[4,5]]
# positive indexing
print(l[0])

# Negative indexing
print(l[-1][-1])


# slicing

l = [1,2,3,4,5,6]

print(l[0:3])
print(l[-3::-1])

# %% [markdown]
# adding items to list

# %%
# append() -> add element in last of the list
l = [1,2,3,4,5]

l.append(6)
l.append([1,2,3])
l.append('delhi')
print(l)

# %%
# extend([x,y,z]) -> its use to add multiple element in last in list

l = [1,2,3,4]
l.extend([5,6,7,8])
print(l)
l.extend(['delhi'])
print(l)

# %%
# insert() its list method its take two arguments the index where the new element should be inserted and the value of the new element

l=[1,2,3,4,5,6,7]
l.insert(0,'nikesh')
print(l)

# %% [markdown]
# Editing items in a list

# %%
l = [1,2,3,4,5]

l[-1] = 500

l[0:2] =[100,200]
print(l)

# %% [markdown]
# Deleting from list

# %%
# del
l = [1,2,3,4,5]

del(l)

# %%
l = [1,2,3,4,5]
del(l[-1])
print(l)

# %%
l = [1,2,3,4,5]
del(l[2:4])
print(l)

# %%
#  remove() method we just have to provide direct value
l = [1,2,3,4,5]
l.remove(3)
print(l)

# %%
# pop method we have to provide index position if we dont provide index it remove the last  element
l = [1,2,3,4,5]
l.pop(0)
print(l)

# %%
# clear
l = [1,2,3,4,5]
l.clear()

# %% [markdown]
# operation on  list
#
# - Arithmetic
# - Membership
# - Loop

# %%
#  Arithmetic (+,*) concatenation/ merge

l = [1,2,3,4,5]
l2 = [6,7,8,9,10]
print(l+l2)

# %%
#  multuplication
l = [1,2,3,4,5]
l2 = [6,7,8,9,10]

print(l* 3)

# %% [markdown]
# loop

# %%
l = [[[1,2],[3,4],[5,6],[7,8]]]

for i in l:
  for k in i:
    for m in k:
      print(m)

# %% [markdown]
# List function

# %%
# len/min/max/sorted

l =[43,5,79,42,45,78,99,92]
print(len(l))
print(min(l))
print(max(l))
print(sorted(l,reverse=True))

# %%
# count

l =[43,5,79,42,45,78,99,92,5,5,5]
l.count(5)

# %%
# index

l =[43,5,79,42,45,78,99,92,5,5,5]

l.index(5)

# %%
# reverse -> this function reverse the original list that mean it is permanent change
l =[43,5,79,67,42,45,78,99,92,5,5,5]
l.reverse()
print(l)

# %% [markdown]
# list Comprehension
#
# -  [expression  for item in iterable if condition == True]

# %%
#  add 1 to 10in a list
l =[]
for i  in range(1,11):
  l.append(i)
print(l)

# %%
l = [i for i  in range(1,11)]
print(l)

# %%
# scalar multiplication on vector
v = [2,3,4]
s = -3
l = []
for i  in v:
  l.append(i *s)
print(l)

# %%
k = [s*i for i in v]
print(k)

# %%
# printing all the numbers divisible by 5 in the range of 1 to 50

ev = [ i for i in range(1,51) if i %5 == 0]
print(ev)

# %%
# find languages which start with letter p
language = ['java','c','c++','python']
l=[]
for i in language:
  if i.startswith('p'):
    l.append(i)
print(l)

# %%
la = [i for i in language if i.startswith('p')]
print(la)

# %%
words =['jabba','racecar']
palindromes = [word for word in words if word == word[::-1]]

print(palindromes)

# %%
# Nested if with List Comprehension
basket = ['apple', 'guava', 'cherry', 'banana']
my_fruits = ['apple', 'kiwi', 'grapes', 'banana']

x = [ f for f in my_fruits if f in basket if f.startswith('a')]
print(x)

# %% [markdown]
# 2 way to traverse a list:
# - itemwise
# - indexwise

# %%
# item wise
l = [1,2,3,4,5]

for i in l:
  print(i)

# %%
# indexwise
l = [1,2,3,4,5]

for i in range(0,len(l)):
  print(l[i])

# %% [markdown]
# The zip() function returns a zip object, which is an iterator of tuples where the first item in each passed iterator is paired together
# and then the second item in each passed iterator are paired together.
#
# If the passed iterators have different lengths, the iterator with the least items decides the length of the new iterator.

# %%
l1 = [1,2,3,4]
l2=[-1,-2,-3,-4]

list(zip(l1,l2))

[i+j  for i,j in zip(l1,l2)]

# %% [markdown]
# 1. Create a list comprehension to generate a list of squares of numbers from 1 to 10

# %%
l=[i**2 for i in range(1,11) ]
print(l)

# %% [markdown]
# 2. Use list comprehension to extract vowels from a given string.

# %%
string = input('enter ')
vowels = 'aeiouAEIOU'
x = [i for i in string if i in vowels]
print(x)

# %% [markdown]
# 3. Generate a list of even numbers using list comprehension.

# %%
even = [i for i in range(1,11) if i % 2 ==0]
print(even)

# %% [markdown]
# 4. Create a list comprehension to find common elements between two lists.

# %%
l = [1,2,3,4,5,6,7,8,9]
l2 = [4,5,7,2]

x=[i for i in l if i in l2]
print(x)

# %% [markdown]
# 5.Use list comprehension to convert a list of strings to uppercase.

# %%
string = ['nikesh','singh']
x= [ i.upper() for i in string ]
print(x)

# %% [markdown]
# 6. Generate a list of tuples containing numbers and their squares.

# %%
# prompt: Generate a list of tuples containing numbers and their squares.

l = [(i, i**2)  for i in range(1,11)]
print(l)

# %% [markdown]
# 7. Use list comprehension to filter out negative numbers from a list.

# %%
l = [1,-1,2,-4,-5,-6,7,8,9]

neg = [i for i  in  l if i <0]
print(neg)

# %% [markdown]
# 8. Create a list comprehension to flatten a list of lists.

# %%
matrix = [[1,2,3],[4,5,6]]

x=  [k for i in matrix for k in i]
print(x)

# %% [markdown]
# 9. Generate a list of prime numbers up to a given number using list comprehension.

# %% [markdown]
# 10. Use list comprehension to find the length of each word in a sentence.

# %%
l= ' hello i am nikeh'

x= [len(i) for i in l.split()]
print(x)

# %% [markdown]
# 11. Create a list comprehension to calculate the sum of each sublist in a list of lists.

# %%
list_of_list = [[1,2],[3,4],[5,6],[7,8]]
sub_list =[sum(sublist) for sublist in list_of_list]
print(sub_list)

# %% [markdown]
# 12. Generate a list of unique characters from a given string using list comprehension.

# %%
l= 'i am nikesh singh'

z = list(set(l))
print(z)

# %% [markdown]
# 13.  Use list comprehension to find elements that occur more than once in a list.

# %%
l = [1,2,1,2,3,4,5,5]
x = [i for i  in l if l.count(i) > 1]
print(x)

# %% [markdown]
# 14. Create a list comprehension to remove vowels from a given string.

# %%
st = 'i am nikesh singh'
vowels  = 'aeiouAEIOU'

x = ' '.join([ i for i in st if i not in vowels ])
print(x)

# %%
k = input()
l=[]
for i in k:
  if i not in 'AEIOUaeiou':
    l.append(i)
print(l)

# %% [markdown]
# 15. Generate a list of Fibonacci numbers using list comprehension.

# %%
# Generate a list of Fibonacci numbers up to n
n = 10

fib = [0,1]
[fib.append(fib[i-1] + fib[i-2] for i in range(2,n))]

print(fib)

# %% [markdown]
# 16.
# Generate a list of palindromes using list comprehension.

# %%
words = ['racecar']

p = [word for word in words if word == word[::-1]]

print(p)
